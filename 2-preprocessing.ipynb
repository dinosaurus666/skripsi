# %%
# !pip install pandas==1.3.2
# !pip install swifter
# !pip install Sastrawi
# Out:
# Collecting pandas==1.3.2
#   Downloading pandas-1.3.2.tar.gz (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 2.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [242 lines of output]
#   Ignoring numpy: markers 'python_version == "3.7" and (platform_machine != "arm64" or platform_system != "Darwin") and platform_machine != "aarch64"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.8" and (platform_machine != "arm64" or platform_system != "Darwin") and platform_machine != "aarch64"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_machine == "aarch64"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.8" and platform_machine == "aarch64"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.8" and platform_machine == "arm64" and platform_system == "Darwin"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.9" and platform_machine == "arm64" and platform_system == "Darwin"' don't match your environment
#   Collecting setuptools>=51.0.0
#     Downloading setuptools-63.4.3-py3-none-any.whl (1.2 MB)
#        ---------------------------------------- 1.2/1.2 MB 3.4 MB/s eta 0:00:00
#   Collecting wheel
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting Cython<3,>=0.29.21
#     Downloading Cython-0.29.32-py2.py3-none-any.whl (986 kB)
#        -------------------------------------- 986.3/986.3 kB 3.3 MB/s eta 0:00:00
#   Collecting numpy==1.19.3
#     Downloading numpy-1.19.3.zip (7.3 MB)
#        ---------------------------------------- 7.3/7.3 MB 3.3 MB/s eta 0:00:00
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Preparing metadata (pyproject.toml): started
#     Preparing metadata (pyproject.toml): finished with status 'error'
#     error: subprocess-exited-with-error
#
#     Preparing metadata (pyproject.toml) did not run successfully.
#     exit code: 1
#
#     [202 lines of output]
#     setup.py:67: RuntimeWarning: NumPy 1.19.3 may not yet support Python 3.10.
#       warnings.warn(
#     Running from numpy source directory.
#     setup.py:480: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates
#       run_build = parse_setuppy_commands()
#     Processing numpy/random\_bounded_integers.pxd.in
#     Processing numpy/random\bit_generator.pyx
#     Processing numpy/random\mtrand.pyx
#     Processing numpy/random\_bounded_integers.pyx.in
#     Processing numpy/random\_common.pyx
#     Processing numpy/random\_generator.pyx
#     Processing numpy/random\_mt19937.pyx
#     Processing numpy/random\_pcg64.pyx
#     Processing numpy/random\_philox.pyx
#     Processing numpy/random\_sfc64.pyx
#     Cythonizing sources
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#       libraries blis not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#       libraries openblas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries tatlas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#       libraries satlas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\aldi\AppData\Local\Temp\pip-install-_dam6hcz\numpy_dcee422b809d4abdaee8c1cb08420f8b\numpy\distutils\system_info.py:1914: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       if self._calc_info(blas):
#     blas_info:
#       libraries blas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     C:\Users\aldi\AppData\Local\Temp\pip-install-_dam6hcz\numpy_dcee422b809d4abdaee8c1cb08420f8b\numpy\distutils\system_info.py:1914: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       if self._calc_info(blas):
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\aldi\AppData\Local\Temp\pip-install-_dam6hcz\numpy_dcee422b809d4abdaee8c1cb08420f8b\numpy\distutils\system_info.py:1914: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       if self._calc_info(blas):
#       NOT AVAILABLE
#
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#       libraries mkl_rt not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#       libraries openblas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#       libraries openblas,lapack not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#       libraries flame not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries tatlas,tatlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries lapack_atlas not found in C:\
#       libraries tatlas,tatlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#       libraries tatlas,tatlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries satlas,satlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries lapack_atlas not found in C:\
#       libraries satlas,satlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#       libraries satlas,satlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries lapack_atlas not found in C:\
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries f77blas,cblas,atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries lapack_atlas not found in C:\
#       libraries f77blas,cblas,atlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#       libraries f77blas,cblas,atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#       libraries lapack not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     C:\Users\aldi\AppData\Local\Temp\pip-install-_dam6hcz\numpy_dcee422b809d4abdaee8c1cb08420f8b\numpy\distutils\system_info.py:1748: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       return getattr(self, '_calc_info_{}'.format(name))()
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\aldi\AppData\Local\Temp\pip-install-_dam6hcz\numpy_dcee422b809d4abdaee8c1cb08420f8b\numpy\distutils\system_info.py:1748: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       return getattr(self, '_calc_info_{}'.format(name))()
#       NOT AVAILABLE
#
#     numpy_linalg_lapack_lite:
#       FOUND:
#         language = c
#         define_macros = [('HAVE_BLAS_ILP64', None), ('BLAS_SYMBOL_SUFFIX', '64_')]
#
#     C:\Users\aldi\AppData\Local\Temp\pip-build-env-e4hnihyv\overlay\Lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running dist_info
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.10
#     creating build\src.win-amd64-3.10\numpy
#     creating build\src.win-amd64-3.10\numpy\distutils
#     building library "npymath" sources
#     error: Microsoft Visual C++ 14.0 is required. Get it with "Build Tools for Visual Studio": https://visualstudio.microsoft.com/downloads/
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#   error: metadata-generation-failed
#
#   Encountered error while generating package metadata.
#
#   See above for output.
#
#   note: This is an issue with the package mentioned above, not pip.
#   hint: See above for details.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# pip subprocess to install build dependencies did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting swifter
#   Downloading swifter-1.3.3.tar.gz (821 kB)
#      -------------------------------------- 821.7/821.7 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas>=1.0.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from swifter) (1.4.3)
# Requirement already satisfied: psutil>=5.6.6 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from swifter) (5.9.1)
# Collecting dask[dataframe]>=2.10.0
#   Downloading dask-2022.8.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 3.1 MB/s eta 0:00:00
# Collecting tqdm>=4.33.0
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.4/78.4 kB 1.5 MB/s eta 0:00:00
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-7.7.1-py2.py3-none-any.whl (123 kB)
#      -------------------------------------- 123.4/123.4 kB 2.4 MB/s eta 0:00:00
# Collecting cloudpickle>=0.2.2
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: parso>0.4.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from swifter) (5.0.1)
# Requirement already satisfied: webencodings in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      -------------------------------------- 141.2/141.2 kB 2.1 MB/s eta 0:00:00
# Collecting toolz>=0.8.2
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.8/55.8 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (21.3)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Collecting pyyaml>=5.3.1
#   Downloading PyYAML-6.0-cp310-cp310-win_amd64.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.23.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.0.0->swifter) (6.15.1)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
#      -------------------------------------- 245.3/245.3 kB 3.0 MB/s eta 0:00:00
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=4.0.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.0.0->swifter) (8.4.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.0.0->swifter) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: colorama in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.33.0->swifter) (0.4.5)
# Requirement already satisfied: tornado>=6.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (7.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.1.3)
# Requirement already satisfied: debugpy>=1.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.6.2)
# Requirement already satisfied: stack-data in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.3.0)
# Requirement already satisfied: backcall in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.12.0)
# Requirement already satisfied: decorator in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.30)
# Requirement already satisfied: setuptools>=18.5 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (63.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->dask[dataframe]>=2.10.0->swifter) (3.0.9)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.4.12)
# Requirement already satisfied: entrypoints in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: jinja2 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.1.2)
# Requirement already satisfied: nbformat in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.4.0)
# Requirement already satisfied: argon2-cffi in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.15.0)
# Requirement already satisfied: prometheus-client in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: wcwidth in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: executing in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.9.1)
# Requirement already satisfied: pure-eval in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.0.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (304)
# Requirement already satisfied: beautifulsoup4 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: defusedxml in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: tinycss2 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.6.6)
# Requirement already satisfied: jupyterlab-pygments in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.9.1)
# Requirement already satisfied: fastjsonschema in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.0.7)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.3.2.post1)
# Requirement already satisfied: pycparser in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.21)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py): started
#   Building wheel for swifter (setup.py): finished with status 'done'
#   Created wheel for swifter: filename=swifter-1.3.3-py3-none-any.whl size=16231 sha256=36d078d86e370d5975e32e0a2853acb0bdc816fb97e77763e28f63de6f00c674
#   Stored in directory: c:\users\aldi\appdata\local\pip\cache\wheels\d5\2a\84\464d249f4c142a606c036c345fe13fb4e66c8e9943c5b3d9be
# Successfully built swifter
# Installing collected packages: tqdm, toolz, pyyaml, locket, jupyterlab-widgets, fsspec, cloudpickle, partd, dask, widgetsnbextension, ipywidgets, swifter
# Successfully installed cloudpickle-2.1.0 dask-2022.8.0 fsspec-2022.7.1 ipywidgets-7.7.1 jupyterlab-widgets-1.1.1 locket-1.0.0 partd-1.2.0 pyyaml-6.0 swifter-1.3.3 toolz-0.12.0 tqdm-4.64.0 widgetsnbextension-3.6.1
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      -------------------------------------- 209.7/209.7 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# !pip install pandas==1.3.2
# Out:
# Collecting pandas==1.3.2
#   Using cached pandas-1.3.2.tar.gz (4.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [239 lines of output]
#   Ignoring numpy: markers 'python_version == "3.7" and (platform_machine != "arm64" or platform_system != "Darwin") and platform_machine != "aarch64"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.8" and (platform_machine != "arm64" or platform_system != "Darwin") and platform_machine != "aarch64"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_machine == "aarch64"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.8" and platform_machine == "aarch64"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.8" and platform_machine == "arm64" and platform_system == "Darwin"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.9" and platform_machine == "arm64" and platform_system == "Darwin"' don't match your environment
#   Collecting setuptools>=51.0.0
#     Using cached setuptools-63.4.3-py3-none-any.whl (1.2 MB)
#   Collecting wheel
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting Cython<3,>=0.29.21
#     Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
#   Collecting numpy==1.19.3
#     Using cached numpy-1.19.3.zip (7.3 MB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Preparing metadata (pyproject.toml): started
#     Preparing metadata (pyproject.toml): finished with status 'error'
#     error: subprocess-exited-with-error
#
#     Preparing metadata (pyproject.toml) did not run successfully.
#     exit code: 1
#
#     [202 lines of output]
#     setup.py:67: RuntimeWarning: NumPy 1.19.3 may not yet support Python 3.10.
#       warnings.warn(
#     Running from numpy source directory.
#     setup.py:480: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates
#       run_build = parse_setuppy_commands()
#     Processing numpy/random\_bounded_integers.pxd.in
#     Processing numpy/random\bit_generator.pyx
#     Processing numpy/random\mtrand.pyx
#     Processing numpy/random\_bounded_integers.pyx.in
#     Processing numpy/random\_common.pyx
#     Processing numpy/random\_generator.pyx
#     Processing numpy/random\_mt19937.pyx
#     Processing numpy/random\_pcg64.pyx
#     Processing numpy/random\_philox.pyx
#     Processing numpy/random\_sfc64.pyx
#     Cythonizing sources
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#       libraries blis not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#       libraries openblas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries tatlas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#       libraries satlas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\aldi\AppData\Local\Temp\pip-install-yq8v2ba9\numpy_d48f1c9db2154a75a42d04e2c2e15642\numpy\distutils\system_info.py:1914: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       if self._calc_info(blas):
#     blas_info:
#       libraries blas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     C:\Users\aldi\AppData\Local\Temp\pip-install-yq8v2ba9\numpy_d48f1c9db2154a75a42d04e2c2e15642\numpy\distutils\system_info.py:1914: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       if self._calc_info(blas):
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\aldi\AppData\Local\Temp\pip-install-yq8v2ba9\numpy_d48f1c9db2154a75a42d04e2c2e15642\numpy\distutils\system_info.py:1914: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       if self._calc_info(blas):
#       NOT AVAILABLE
#
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#       libraries mkl_rt not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#       libraries openblas not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#       libraries openblas,lapack not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#       libraries flame not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries tatlas,tatlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries lapack_atlas not found in C:\
#       libraries tatlas,tatlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#       libraries tatlas,tatlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries satlas,satlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries lapack_atlas not found in C:\
#       libraries satlas,satlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#       libraries satlas,satlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries lapack_atlas not found in C:\
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries f77blas,cblas,atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\lib
#       libraries lapack_atlas not found in C:\
#       libraries f77blas,cblas,atlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#       libraries f77blas,cblas,atlas not found in C:\Users\aldi\AppData\Local\Programs\Python\Python310\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#       libraries lapack not found in ['C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\aldi\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#       NOT AVAILABLE
#
#     C:\Users\aldi\AppData\Local\Temp\pip-install-yq8v2ba9\numpy_d48f1c9db2154a75a42d04e2c2e15642\numpy\distutils\system_info.py:1748: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       return getattr(self, '_calc_info_{}'.format(name))()
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\aldi\AppData\Local\Temp\pip-install-yq8v2ba9\numpy_d48f1c9db2154a75a42d04e2c2e15642\numpy\distutils\system_info.py:1748: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       return getattr(self, '_calc_info_{}'.format(name))()
#       NOT AVAILABLE
#
#     numpy_linalg_lapack_lite:
#       FOUND:
#         language = c
#         define_macros = [('HAVE_BLAS_ILP64', None), ('BLAS_SYMBOL_SUFFIX', '64_')]
#
#     C:\Users\aldi\AppData\Local\Temp\pip-build-env-3pyjhupd\overlay\Lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running dist_info
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.10
#     creating build\src.win-amd64-3.10\numpy
#     creating build\src.win-amd64-3.10\numpy\distutils
#     building library "npymath" sources
#     error: Microsoft Visual C++ 14.0 is required. Get it with "Build Tools for Visual Studio": https://visualstudio.microsoft.com/downloads/
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#   error: metadata-generation-failed
#
#   Encountered error while generating package metadata.
#
#   See above for output.
#
#   note: This is an issue with the package mentioned above, not pip.
#   hint: See above for details.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# pip subprocess to install build dependencies did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import string
import re
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import nltk
import csv
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 from sklearn.feature_extraction.text import CountVectorizer
#       4 import string
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install Matplotlib
# Out:
# Collecting Matplotlib
#   Downloading matplotlib-3.5.3-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 3.6 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib) (1.23.1)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.3/55.3 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib) (3.0.9)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.34.4-py3-none-any.whl (944 kB)
#      -------------------------------------- 944.1/944.1 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib) (2.8.2)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->Matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, Matplotlib
# Successfully installed Matplotlib-3.5.3 cycler-0.11.0 fonttools-4.34.4 kiwisolver-1.4.4 pillow-9.2.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import string
import re
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import nltk
import csv
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from sklearn.feature_extraction.text import CountVectorizer
#       4 import string
#       5 import re
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.2-cp310-cp310-win_amd64.whl (7.4 MB)
#      ---------------------------------------- 7.4/7.4 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.23.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.0-cp310-cp310-win_amd64.whl (38.6 MB)
#      ---------------------------------------- 38.6/38.6 MB 2.3 MB/s eta 0:00:00
# Collecting joblib>=1.0.0
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      -------------------------------------- 307.0/307.0 kB 1.7 MB/s eta 0:00:00
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1304 sha256=a9b2210946ff9798b60e43e7db36ba9499132a72fcfdb375e0bd910b890e8008
#   Stored in directory: c:\users\aldi\appdata\local\pip\cache\wheels\9b\13\01\6f3a7fd641f90e1f6c8c7cded057f3394f451f340371c68f3d
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.1.0 scikit-learn-1.1.2 scipy-1.9.0 sklearn-0.0 threadpoolctl-3.1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import string
import re
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import nltk
import csv
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [9], in <cell line: 8>()
#       6 from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
#       7 from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# ----> 8 import nltk
#       9 import csv
#      10 nltk.download('punkt')
#
# ModuleNotFoundError: No module named 'nltk'

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 4.8 MB/s eta 0:00:00
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.6/96.6 kB 5.8 MB/s eta 0:00:00
# Collecting regex>=2021.8.3
#   Downloading regex-2022.7.25-cp310-cp310-win_amd64.whl (262 kB)
#      -------------------------------------- 262.7/262.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.64.0)
# Requirement already satisfied: colorama in c:\users\aldi\appdata\local\programs\python\python310\lib\site-packages (from click->nltk) (0.4.5)
# Installing collected packages: regex, click, nltk
# Successfully installed click-8.1.3 nltk-3.7 regex-2022.7.25

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import string
import re
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import nltk
import csv
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aldi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aldi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\aldi\Komentar_Youtube(test2).csv')
df.head()
# Out:
#    Unnamed: 0                                           komentar
# 0           0  Sy vaksin 7 mei jam 10 pagi... \nSetelah vaksi...
# 1           1                                             Aamiin
# 2           2         Yg d hawatirkan itu epek jangka panjangnya
# 3           3  Setelah vaksin siang jam 12 malam tidur terban...
# 4           4  Saya 53 th, tinggal di Jerman telah di vaksin ...

# %%
del df['Unnamed: 0']
df.head()
# Out:
#                                             komentar
# 0  Sy vaksin 7 mei jam 10 pagi... \nSetelah vaksi...
# 1                                             Aamiin
# 2         Yg d hawatirkan itu epek jangka panjangnya
# 3  Setelah vaksin siang jam 12 malam tidur terban...
# 4  Saya 53 th, tinggal di Jerman telah di vaksin ...

# %%
#cleaning Text
#membersihkan kalimat dari tanda baca seperti titik, koma, emotikon
def remove_punct(text):
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r"\b[a-zA-Z]\b", "", text)
    text = re.sub(r'\b\w(1,2)\b', '', text)
    text = re.sub(r'\s\s+', ' ', text)
    text = re.sub(r"\d+", "", text)
    return text
df['komentar'] = df['komentar'].apply(remove_punct)

# %%
#no need
df.head()
# Out:
#                                             komentar
# 0  Sy vaksin  mei jam  pagi Setelah vaksin tidur ...
# 1                                             Aamiin
# 2           Yg hawatirkan itu epek jangka panjangnya
# 3  Setelah vaksin siang jam  malam tidur terbangu...
# 4  Saya  th tinggal di Jerman telah di vaksin Ast...

# %%
# ------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
#membuat huruf besar menjadi huruf kecil
df['komentar'] = df['komentar'].str.lower()
df.head()
# Out:
#                                             komentar
# 0  sy vaksin  mei jam  pagi setelah vaksin tidur ...
# 1                                             aamiin
# 2           yg hawatirkan itu epek jangka panjangnya
# 3  setelah vaksin siang jam  malam tidur terbangu...
# 4  saya  th tinggal di jerman telah di vaksin ast...

# %%
#no need
df.count()
# Out:
# komentar    62
# dtype: int64

# %%
def replace_repeat_character(text):
    # Pattern to look for three or more repetitions of any character, including newlines (contoh goool -> gol).
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL)
    return pattern.sub(r"\1\1", text)

df['komentar'] = df['komentar'].apply(replace_repeat_character) 
df.head()
# Out:
#                                             komentar
# 0  sy vaksin  mei jam  pagi setelah vaksin tidur ...
# 1                                             aamiin
# 2           yg hawatirkan itu epek jangka panjangnya
# 3  setelah vaksin siang jam  malam tidur terbangu...
# 4  saya  th tinggal di jerman telah di vaksin ast...

# %%
from nltk.tokenize import word_tokenize

def tokenize(text):
    return nltk.word_tokenize(text)
    
df['TOKENIZATION'] = df['komentar'].apply(tokenize)
df.head(10)
# Out:
#                                             komentar  \
# 0  sy vaksin  mei jam  pagi setelah vaksin tidur ...
# 1                                             aamiin
# 2           yg hawatirkan itu epek jangka panjangnya
# 3  setelah vaksin siang jam  malam tidur terbangu...
# 4  saya  th tinggal di jerman telah di vaksin ast...
# 5  sy sekeluarga tetep nunggu vaksin nusantara aj...
# 6  alhamdulillah yang sudah di vaksin semoga seha...
# 7  saya tadi siang vaksin pertama astra di pasar ...
# 8  saya vaksin astrazeneca tgl  mei pagi malamnya...
# 9  saya pun sudah disuntik dgn vaksin az nie teng...
#
#                                         TOKENIZATION
# 0  [sy, vaksin, mei, jam, pagi, setelah, vaksin, ...
# 1                                           [aamiin]
# 2    [yg, hawatirkan, itu, epek, jangka, panjangnya]
# 3  [setelah, vaksin, siang, jam, malam, tidur, te...
# 4  [saya, th, tinggal, di, jerman, telah, di, vak...
# 5  [sy, sekeluarga, tetep, nunggu, vaksin, nusant...
# 6  [alhamdulillah, yang, sudah, di, vaksin, semog...
# 7  [saya, tadi, siang, vaksin, pertama, astra, di...
# 8  [saya, vaksin, astrazeneca, tgl, mei, pagi, ma...
# 9  [saya, pun, sudah, disuntik, dgn, vaksin, az, ...

# %%
import pickle
import os
current_dir = os.path.dirname(r'C:\Users\aldi')
kamus_katabaku= pickle.load(open(os.path.join(current_dir,
                'aldi',
                 'kamus_katabaku.pkl'), 'rb'))

# %%
print(kamus_katabaku)
# Out:
# {'woww': 'wow', 'aminn': 'amin', 'met': 'selamat', 'netaas': 'menetas', 'keberpa': 'keberapa', 'eeeehhhh': 'eh', 'kata2nyaaa': 'kata-katanya', 'hallo': 'halo', 'kaka': 'kakak', 'ka': 'kak', 'daah': 'dah', 'aaaaahhhh': 'ah', 'yaa': 'ya', 'smga': 'semoga', 'slalu': 'selalu', 'amiin': 'amin', 'kk': 'kakak', 'trus': 'terus', 'sii': 'sih', 'nyenengin': 'menyenangkan', 'bgt': 'sangat', 'gemess': 'gemas', 'akuuu': 'aku', 'jgn': 'jangan', 'udah': 'sudah', 'gitu': 'begitu', 'aja': 'saja', 'gemesiin': 'menggemaskan', 'menyenangkn': 'menyenangkan', 'rb': 'ribu', 'akau': 'aku', 'saranin': 'menyarankan', 'nemuin': 'menemukan', 'yah': 'ya', 'mnis2nya': 'manis-manisnya', 'gtu': 'begitu', 'tu': 'itu', 'idolaa': 'idola', 'bangett': 'banget', 'kaakk': 'kak', 'baaiikkk': 'baik', 'telaatt': 'telat', 'kaak': 'kak', 'yg': 'yang', 'lg': 'lagi', 'skarang': 'sekarang', 'sempet': 'sempat', 'karna': 'karena', 'ngga': 'tidak', 'mantep': 'mantap', 'loohhh': 'loh', 'yeee': 'ya', 'baguuuuus': 'bagus', 'sampe': 'sampai', 'ngikutin': 'mengikuti', 'gayany': 'gayanya', 'bnk': 'bang', 'awaas': 'awas', 'siip': 'sip', 'abizzzz': 'habis', 'kerrrrennnn': 'keren', 'sayaa': 'saya', 'pengen': 'ingin', 'kpan': 'kapan', 'sma': 'sama', 'sdkit': 'sedikit', 'bngt': 'sangat', 'lgu': 'lagu', 'bener2': 'benar-benar', 'kharismanya': 'karismanya', 'aq': 'aku', 'jdi': 'jadi', 'lgi': 'lagi', 'gk': 'tidak', 'kek': 'kayak', 'lgunya': 'lagunya', 'kereeeeennnn': 'keren', 'nyamain': 'menyamakan', 'lakik': 'laki', 'siippp': 'sip', 'bkn': 'bukan', 'nyangka': 'menyangka', 'bangettt': 'banget', 'kereeen': 'keren', 'wihhhhhh': 'wih', 'tp': 'tapi', 'inget': 'ingat', 'bingitsss': 'banget', 'dmn': 'dimana', 'bird': 'biru', 'kaloo': 'kalo', 'gimna': 'bagaimana', 'tuuh': 'tuh', 'nyebur': 'mencebur', 'yng': 'yang', 'dbuat': 'dibuat', 'kn': 'kan', 'org': 'orang', 'pingin': 'pengin', 'bangcat': 'bangsat', 'yha': 'ya', 'waoohhh': 'wah', 'pngn': 'ingin', 'tmpt': 'tempat', 'dhe': 'deh', 'indahhh': 'indah', 'bgttt': 'banget', 'tuhh': 'tuh', 'berarto': 'berarti', 'ga': 'enggak', 'aamiin': 'amin', 'amiiinn': 'amin', 'dgn': 'dengan', 'aminnnn2': 'amin-amin', 'amiiiin': 'amin', 'aminnn': 'amin', 'amiend': 'amien', 'yaaa': 'ya', 'ameen': 'amin', 'aminnnn': 'amin', 'amiiinnn': 'amin', 'ngomong': 'mengomong', 'mamer': 'memamerkan', 'keles': 'kali', 'jelase': 'jelas', 'liat': 'lihat', 'uwakk': 'uwak', 'ntar': 'nanti', 'bs': 'bisa', 'gini': 'ini', 'salfok': 'salah fokus', 'njir': 'anjir', 'piiink': 'pink', 'astgfrullah': 'astagfirullah', 'ko': 'kok', 'cd': 'celana dalam', 'gbs': 'gabisa', 'bhs': 'bahasa', 'yaaaaaa': 'ya', 'gak': 'tidak', 'bangshad': 'bangsat', 'stagahhhh': 'astaga', 'kpn': 'kapan', 'iooo': 'lo', 'dy': 'dia', 'd': 'di', 'mslh': 'masalah', 'qt': 'kita', 'plampiasannn': 'pelampiasan', 'masalahh': 'masalah', 'tohh': 'toh', 'inghinn': 'ingin', 'dhi': 'di', 'mengherthii': 'mengerti', 'yanckh': 'yang', 'chelalyyu': 'selalu', 'therchakitty': 'tersakiti', 'mauuuuu': 'mau', 'kaliii': 'kali', 'bangat': 'banget', 'bkin': 'bikin', 'dongg': 'dong', 'yokkk': 'yuk', 'yu': 'yuk', 'sweger': 'segar', 'gantengg': 'ganteng', 'bingiit': 'banget', 'kebukaaa': 'terbuka', 'tpi': 'tapi', 'keliatan': 'kelihatan', 'yakk': 'ya', 'kayakk': 'kayak', 'asliii': 'asli', 'kyk': 'kayak', 'cntiknya': 'cantiknya', 'bat': 'banget', 'ngeliatnya': 'melihatnya', 'sll': 'selalu', 'bet': 'banget', 'njerr': 'anjir', 'bingiiittttzzzz': 'banget', 'k': 'ke', 'klo': 'kalau', 'dooong': 'dong', 'masi': 'masih', 'gni': 'begini', 'hdk': 'hendak', 'jugaa': 'juga', 'mksud': 'maksud', 'aj': 'saja', 'tetep': 'tetap', 'mbakx': 'mbaknya', 'syantik': 'cantik', 'kite': 'kita', 'pa': 'apa', 'mksd': 'maksud', 'bejilbbnya': 'berjilbabnya', 'masio': 'masih', 'yahhh': 'ya', 'makasih': 'terima kasih', 'leh': 'boleh', 'ugaaa': 'juga', 'jerewi': 'jerawat', 'ilang': 'hilang', 'jilbabnyaah': 'jilbabnya', 'yuuuk': 'yuk', 'warnaaa': 'warna', 'punyaaa': 'punya', 'cantiik': 'cantik', 'sukaaak': 'suka', 'kebayanyaa': 'kebayanya', 'mantes': 'memantas', 'merekaaaa': 'mer ...

# %%
def normalized_term(text):
    return [kamus_katabaku[term] if term in kamus_katabaku else term for term in text]
df['TOKENIZATION'] = df['TOKENIZATION'].apply(normalized_term) 
df.head(10)
# Out:
#                                             komentar  \
# 0  sy vaksin  mei jam  pagi setelah vaksin tidur ...
# 1                                             aamiin
# 2           yg hawatirkan itu epek jangka panjangnya
# 3  setelah vaksin siang jam  malam tidur terbangu...
# 4  saya  th tinggal di jerman telah di vaksin ast...
# 5  sy sekeluarga tetep nunggu vaksin nusantara aj...
# 6  alhamdulillah yang sudah di vaksin semoga seha...
# 7  saya tadi siang vaksin pertama astra di pasar ...
# 8  saya vaksin astrazeneca tgl  mei pagi malamnya...
# 9  saya pun sudah disuntik dgn vaksin az nie teng...
#
#                                         TOKENIZATION
# 0  [saya, vaksin, mei, jam, pagi, setelah, vaksin...
# 1                                             [amin]
# 2  [yang, hawatirkan, itu, efek, jangka, panjangnya]
# 3  [setelah, vaksin, siang, jam, malam, tidur, te...
# 4  [saya, tahu, tinggal, di, jerman, telah, di, v...
# 5  [saya, sekeluarga, tetap, tunggu, vaksin, nusa...
# 6  [alhamdulillah, yang, sudah, di, vaksin, semog...
# 7  [saya, tadi, siang, vaksin, pertama, astrazene...
# 8  [saya, vaksin, astrazeneca, tanggal, mei, pagi...
# 9  [saya, pun, sudah, disuntik, dengan, vaksin, a...

# %%
#menambahkan kata kata yang akan di hapus
stopword =nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                 'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                 'krn', 'nya', 'nih', 'sih', 
                 'si', 'tau', 'tuh', 'utk', 'ya','sdh',
                 'aja', 'n', 't', 'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                 '&amp', 'yah', 'njir', 'wkwk', 'haha', 'hehe', 'rs', 'yaa',
                 'nii', 'bin', 'lahh', 'hmm', 'lieur', 'njarem', 'kale',
                 'hd', 'an', 'ob', 'bro', 'ud', 'iyaa', 'guys', 'doang',
                 'doank', 'eh', 'kek', 'or', 'kah', 'eso', 'tuh', 'dh', 'dnk',
                 'mh', 'ja', 'tu', 'anu', 'ni', 'ku', 'blz', 'gy', 'skg', 'eeh',
                 'pas','tar','bc','x','dong','d'])

# %%
#tidak direkomendasikan
word_list=['enggak','tidak','jangan','belum']
stopword = [word for word in stopword if word not in word_list] #make a copy of the word_list

# %%
def remove_stopwords(text):
    return [word for word in text if word not in stopword]
    
df['STOP_REMOVAL'] = df['TOKENIZATION'].apply(remove_stopwords)
df.head(10)
# Out:
#                                             komentar  \
# 0  sy vaksin  mei jam  pagi setelah vaksin tidur ...
# 1                                             aamiin
# 2           yg hawatirkan itu epek jangka panjangnya
# 3  setelah vaksin siang jam  malam tidur terbangu...
# 4  saya  th tinggal di jerman telah di vaksin ast...
# 5  sy sekeluarga tetep nunggu vaksin nusantara aj...
# 6  alhamdulillah yang sudah di vaksin semoga seha...
# 7  saya tadi siang vaksin pertama astra di pasar ...
# 8  saya vaksin astrazeneca tgl  mei pagi malamnya...
# 9  saya pun sudah disuntik dgn vaksin az nie teng...
#
#                                         TOKENIZATION  \
# 0  [saya, vaksin, mei, jam, pagi, setelah, vaksin...
# 1                                             [amin]
# 2  [yang, hawatirkan, itu, efek, jangka, panjangnya]
# 3  [setelah, vaksin, siang, jam, malam, tidur, te...
# 4  [saya, tahu, tinggal, di, jerman, telah, di, v...
# 5  [saya, sekeluarga, tetap, tunggu, vaksin, nusa...
# 6  [alhamdulillah, yang, sudah, di, vaksin, semog...
# 7  [saya, tadi, siang, vaksin, pertama, astrazene...
# 8  [saya, vaksin, astrazeneca, tanggal, mei, pagi...
# 9  [saya, pun, sudah, disuntik, dengan, vaksin, a...
#
#                                         STOP_REMOVAL
# 0  [vaksin, mei, jam, pagi, vaksin, tidur, jam, a...
# 1                                             [amin]
# 2             [hawatirkan, efek, jangka, panjangnya]
# 3  [vaksin, siang, jam, malam, tidur, terbangun, ...
# 4  [tinggal, jerman, vaksin, astrazeneca, februar...
# 5  [sekeluarga, tunggu, vaksin, nusantara, ajahh,...
# 6  [alhamdulillah, vaksin, semoga, sehat, umur, a...
# 7  [siang, vaksin, astrazeneca, pasar, pagi, mang...
# 8  [vaksin, astrazeneca, tanggal, mei, pagi, mala...
# 9  [disuntik, vaksin, astrazeneca, tengahari, ken...

# %%
#tidak di rekomendasikan
factory = StemmerFactory()
stemmer = factory.create_stemmer()
import swifter

# implementasi pada data kita

# stemmed
def stemmed_wrapper(text):
    return stemmer.stem(text)

text_dict = {}

for document in df['STOP_REMOVAL']:
    for text in document:
        if text not in text_dict:
            text_dict[text] = ' '
            
print(len(text_dict))
print("------------------------")

for text in text_dict:
    text_dict[text] = stemmed_wrapper(text)
    print(text,":" ,text_dict[text])
    
print(text_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [text_dict[text] for text in document]
# Out:
# 440
# ------------------------
# vaksin : vaksin
# mei : mei
# jam : jam
# pagi : pagi
# tidur : tidur
# alhamdulillah : alhamdulillah
# tidak : tidak
# kendala : kendala
# malemnya : malemnya
# langsung : langsung
# olahraga : olahraga
# aliran : alir
# darah : darah
# lancar : lancar
# badan : badan
# enakan : enak
# pegal : pegal
# pusing : pusing
# panas : panas
# dingin : dingin
# semoga : moga
# kedepannya : depan
# efek : efek
# samping : samping
# apapun : apa
# amin : amin
# hawatirkan : hawatirkan
# jangka : jangka
# panjangnya : panjang
# siang : siang
# malam : malam
# terbangun : bangun
# menggigil : gigil
# nggreges : nggreges
# orang : orang
# kena : kena
# flu : flu
# meriang : meriang
# minum : minum
# paracetamol : paracetamol
# lumayan : lumayan
# sakit : sakit
# makan : makan
# jeruk : jeruk
# tomat : tomat
# istirahat : istirahat
# jalan : jalan
# sinar : sinar
# tinggal : tinggal
# jerman : jerman
# astrazeneca : astrazeneca
# february : february
# kemarin : kemarin
# berita : berita
# enak : enak
# lengan : lengan
# bekas : bekas
# suntik : suntik
# merasakan : rasa
# sekeluarga : keluarga
# tunggu : tunggu
# nusantara : nusantara
# ajahh : ajahh
# komorbid : komorbid
# sgr : sgr
# rilis : rilis
# berusaha : usaha
# menghalangi : halang
# kepentingan : penting
# pribadinya : pribadi
# sehat : sehat
# umur : umur
# pasar : pasar
# mangga : mangga
# malamnya : malam
# hangat : hangat
# telet : telet
# bawaannya : bawa
# rebahan : rebah
# thanks : thanks
# lord : lord
# tanggal : tanggal
# suhu : suhu
# enggak : enggak
# besok : besok
# paginya : pagi
# suka : suka
# petugas : tugas
# lebaran : lebaran
# disuntik : suntik
# tengahari : tengahari
# demam : demam
# ubat : ubat
# panadol : panadol
# malaysia : malaysia
# rakyat : rakyat
# keluhan : keluh
# teman : teman
# pakai : pakai
# sinovac : sinovac
# jarang : jarang
# kepala : kepala
# mulu : mulu
# ketiga : tiga
# sabtu : sabtu
# minggu : minggu
# pulih : pulih
# ngilu : ngilu
# nyeri : nyeri
# daerah : daerah
# divaksin : vaksin
# jenica : jenica
# gelala : gala
# timbul : timbul
# badanku : badan
# ringan : ringan
# beraktivitas : aktivitas
# terima : terima
# kasih : kasih
# infonya : info
# salam : salam
# indonesia : indonesia
# rotan : rotan
# akar : akar
# buatan : buat
# anak : anak
# bangsa : bangsa
# hemat : hemat
# percaya : percaya
# mual : mual
# tangan : tangan
# jaram : jaram
# membaik : baik
# jumat : jumat
# habis : habis
# zeneca : zeneca
# batch : batch
# viral : viral
# meninggal : tinggal
# hentikan : henti
# merasakqn : merasakqn
# mendingan : mending
# kerja : kerja
# keras : keras
# lemas : lemas
# full : full
# agustus : agustus
# siank : siank
# merasai : rasai
# kerasa : rasa
# kayak : kayak
# muter : muter
# normal : normal
# anjurin : anjurin
# kelapa : kelapa
# muda : muda
# keringat : keringat
# nyentuh : nyentuh
# air : air
# tetangga : tetangga
# bangun : bangun
# faktor : faktor
# imun : imun
# pengalaman : alam
# faedah : faedah
# anjuran : anjur
# penyakit : sakit
# fit : fit
# mending : mending
# doloe : doloe
# bnar : bnar
# kali : kali
# nikah : nikah
# kudu : kudu
# efeknya : efek
# tega : tega
# lihat : lihat
# bb : bb
# turun : turun
# surat : surat
# puskesmas : puskesmas
# catin : catin
# dikasih : kasih
# manten : manten
# dipelosok : pelosok
# aturan : atur
# sungguh : sungguh
# memepersulit : sulit
# jarak : jarak
# lokasi : lokasi
# mantenn : mantenn
# bolak : bolak
# balek : balek
# cuman : cuman
# ngurussin : ngurussin
# ribet : ribet
# pkul : pkul
# sebentar : sebentar
# dokter : dokter
# aztraveneca : aztraveneca
# untung : untung
# aman : aman
# tahap : tahap
# iktiraf : iktiraf
# buah : buah
# negara : negara
# dnia : dnia
# arab : arab
# saudi : saudi
# kbrhsilan : kbrhsilan
# mlawan : mlawan
# varian : varian
# delta : delta
# terimakasih : terimakasih
# informasi : informasi
# berguna : guna
# masyarakat : masyarakat
# mantap : mantap
# penjelasannya : jelas
# membantu : bantu
# ditengah : tengah
# takut : takut
# sept : sept
# pulangnya : pulang
# lahap : lahap
# hijau : hijau
# daya : daya
# tahan : tahan
# tubuhnya : tubuh
# lemah : lemah
# dilarang : larang
# kuat : kuat
# maaf : maaf
# membagi : bagi
# pribadi : pribadi
# eropa : eropa
# tepatnya : tepat
# italy : italy
# sebulan : bulan
# pemerintah : perintah
# gencar : gencar
# objek : objek
# populasi : populasi
# ter : ter
# musim : musim
# diadakan : ada
# masal : masal
# menunggu : tunggu
# giliran : gilir
# dosis : dosis
# edukasinya : edukasi
# hai : hai
# kelelahan : lelah
# menyebabkan : sebab
# lebam : lebam
# biru : biru
# merah : merah
# kaki : kaki
# betis : betis
# paha : paha
# menghilang : hilang
# penggumpalan : gumpal
# kondisi : kondisi
# mohon : mohon
# pencerahan : cerah
# berat : berat
# rasakan : rasa
# berbeda : beda
# sekujur : kujur
# seharian : hari
# total : total
# vaksinasi : vaksinasi
# rutin : rutin
# vitamin : vitamin
# sesudav : sesudav
# jus : jus
# sok : sok
# prepare : prepare
# mengurangi : kurang
# cocok : cocok
# bule : bule
# pengujian : uji
# tesnya : tes
# relawan : rawan
# fisik : fisik
# stamina : stamina
# pemain : main
# bola : bola
# bandingankan : bandingankan
# asia : asia
# tahannya : tahan
# test : test
# relawannya : rawan
# dosisnya : dosis
# sesuaikan : sesuai
# immunotrapi : immunotrapi
# dijadikan : jadi
# alternatif : alternatif
# keraguan : ragu
# konvensional : konvensional
# tolong : tolong
# meminimalisir : meminimalisir
# pembekuan : beku
# anti : anti
# platelet : platelet
# thrombo : thrombo
# aspillets : aspillets
# clopidogrel : clopidogrel
# terima kasih : terima kasih
# dunia : dunia
# upah : upah
# salah : salah
# tujuannya : tuju
# benarkan : benar
# kelak : kelak
# manusia : manusia
# mempertanggungjawabkan : mempertanggungjawabkan
# perbuatannya : buat
# baca : baca
# tulisan : tulis
# pengembangan : kembang
# puluhan : puluh
# mengecek : ecek
# berkelanjutannya : lanjut
# corona : corona
# gejala : gejala
# laper : laper
# beda : beda
# pintar : pintar
# utamakan : utama
# keamanan : aman
# teliti : teliti
# epekyh : epekyh
# tida : tida
# korban : korban
# kasihan : kasihan
# orangindonisia : orangindonisia
# diracuni : racun
# sayh : sayh
# ramuan : ramu
# pahit : pahit
# sajh : sajh
# perhatiannya : perhati
# penjelasan : jelas
# krg : krg
# lugas : lugas
# hrsx : hrsx
# bandingkan : banding
# bahayanya : bahaya
# covid : covid
# jelasin : jelasin
# mengalamai : mengalamai
# sembuh : sembuh
# puji : puji
# tuhan : tuhan
# isu : isu
# persaingan : saing
# bisnis : bisnis
# menjatuhkan : jatuh
# produk : produk
# intinya : inti
# mencelakakan : celaka
# rakyatnya : rakyat
# perkongsian : kongsi
# bermanafaat : bermanafaat
# hubungan : hubung
# hb : hb
# des : des
# diukur : ukur
# donor : donor
# asma : asma
# far : far
# pencetus : cetus
# halo : halo
# busui : busui
# hamil : hamil
# riwayat : riwayat
# pengentalan : kental
# dimer : dimer
# ribu : ribu
# pengidap : idap
# myelitis : myelitis
# transverse : transverse
# ssdhnya : ssdhnya
# juli : juli
# insha : insha
# allah : allah
# genap : genap
# pasca : pasca
# dilengan : leng
# tbc : tbc
# infeksi : infeksi
# paru : paru
# epilepsi : epilepsi
# pfizer : pfizer
# mengalami : alami
# nafsumakan : nafsumakan
# seminggu : minggu
# sore : sore
# punggung : punggung
# susah : susah
# remuk : remuk
# butuh : butuh
# menit : menit
# efeck : efeck
# informasinya : informasi
# pernyataannya : nyata
# netral : netral
# selamat : selamat
# mengganggu : ganggu
# nnya : nnya
# booster : booster
# menstruasi : menstruasi
# lakukan : laku
# jujur : jujur
# god : god
# bless : bless
# you : you
# pemberian : beri
# vacin : vacin
# vacinnya : vacinnya
# kamis : kamis
# keesokkannya : esok
# muncul : muncul
# bintik : bintik
# ruam : ruam
# merata : rata
# bahaya : bahaya
# tubuh : tubuh
# belum : belum
# komen : komen
# netizen : netizen
# top : top
# subcribe : subcribe
# deh : deh
# dos : dos
# rekap : rekap
# jantung : jantung
# hasilnya : hasil
# jaraknya : jarak
# {'vaksin': 'vaksin', 'mei': 'mei', 'jam': 'jam', 'pagi': 'pagi', 'tidur': 'tidur', 'alhamdulillah': 'alhamdulillah', 'tidak': 'tidak', 'kendala': 'kendala', 'malemnya': 'malemnya', 'langsung': 'langsung', 'olahraga': 'olahraga', 'aliran': 'alir', 'darah': 'darah', 'lancar': 'lancar', 'badan': 'badan', 'enakan': 'enak', 'pegal': 'pegal', 'pusing': 'pusing', 'panas': 'panas', 'dingin': 'dingin', 'semoga': 'moga', 'kedepannya': 'depan', 'efek': 'efek', 'samping': 'samping', 'apapun': 'apa', 'amin': 'amin', 'hawatirkan': 'hawatirkan', 'jangka': 'jangka', 'panjangnya': 'panjang', 'siang': 'siang', 'malam': 'malam', 'terbangun': 'bangun', 'menggigil': 'gigil', 'nggreges': 'nggreges', 'orang': 'orang', 'kena': 'kena', 'flu': 'flu', 'meriang': 'meriang', 'minum': 'minum', 'paracetamol': 'paracetamol', 'lumayan': 'lumayan', 'sakit': 'sakit', 'makan': 'makan', 'jeruk': 'jeruk', 'tomat': 'tomat', 'istirahat': 'istirahat', 'jalan': 'jalan', 'sinar': 'sinar', 'tinggal': 'tinggal', 'jerman': 'jerman', 'astrazeneca': 'astrazeneca', 'february': 'february', 'kemarin': 'kemarin', 'berita': 'berita', 'enak': 'enak', 'lengan': 'lengan', 'bekas': 'bekas', 'suntik': 'suntik', 'merasakan': 'rasa', 'sekeluarga': 'keluarga', 'tunggu': 'tunggu', 'nusantara': 'nusantara', 'ajahh': 'ajahh', 'komorbid': 'komorbid', 'sgr': 'sgr', 'rilis': 'rilis', 'berusaha': 'usaha', 'menghalangi': 'halang', 'kepentingan': 'penting', 'pribadinya': 'pribadi', 'sehat': 'sehat', 'umur': 'umur', 'pasar': 'pasar', 'mangga': 'mangga', 'malamnya': 'malam', 'hangat': 'hangat', 'telet': 'telet', 'bawaannya': 'bawa', 'rebahan': 'rebah', 'thanks': 'thanks', 'lord': 'lord', 'tanggal': 'tanggal', 'suhu': 'suhu', 'enggak': 'enggak', 'besok': 'besok', 'paginya': 'pagi', 'suka': 'suka', 'petugas': 'tugas', 'lebaran': 'lebaran', 'disuntik': 'suntik', 'tengahari': 'tengahari', 'demam': 'demam', 'ubat': 'ubat', 'panadol': 'panadol', 'malaysia': 'malaysia', 'rakyat': 'rakyat', 'keluhan': 'keluh', 'teman': 'teman', 'pakai': 'pakai', 'sinovac': 'sinovac', 'jarang': 'jarang', 'kepala': 'kepala', 'mulu': 'mulu', 'ketiga': 'tiga', 'sabtu': 'sabtu', 'minggu': 'minggu', 'pulih': 'pulih', 'ngilu': 'ngilu', 'nyeri': 'nyeri', 'daerah': 'daerah', 'divaksin': 'vaksin', 'jenica': 'jenica', 'gelala': 'gala', 'timbul': 'timbul', 'badanku': 'badan', 'ringan': 'ringan', 'beraktivitas': 'aktivitas', 'terima': 'terima', 'kasih': 'kasih', 'infonya': 'info', 'salam': 'salam', 'indonesia': 'indonesia', 'rotan': 'rotan', 'akar': 'akar', 'buatan': 'buat', 'anak': 'anak', 'bangsa': 'bangsa', 'hemat': 'hemat', 'percaya': 'percaya', 'mual': 'mual', 'tangan': 'tangan', 'jaram': 'jaram', 'membaik': 'baik', 'jumat': 'jumat', 'habis': 'habis', 'zeneca': 'zeneca', 'batch': 'batch', 'viral': 'viral', 'meninggal': 'tinggal', 'hentikan': 'henti', 'merasakqn': 'merasakqn', 'mendingan': 'mending', 'kerja': 'kerja', 'keras': 'keras', 'lemas': 'lemas', 'full': 'full', 'agustus': 'agustus', 'siank': 'siank', 'merasai': 'rasai', 'kerasa': 'rasa', 'kayak': 'kayak', 'muter': 'muter', 'normal': 'normal', 'anjurin': 'anjurin', 'kelapa': 'kelapa', 'muda': 'muda', 'keringat': 'keringat', 'nyentuh': 'nyentuh', 'air': 'air', 'tetangga': 'tetangga', 'bangun': 'bangun', 'faktor': 'faktor', 'imun': 'imun', 'pengalaman': 'alam', 'faedah': 'faedah', 'anjuran': 'anjur', 'penyakit': 'sakit', 'fit': 'fit', 'mending': 'mending', 'doloe': 'doloe', 'bnar': 'bnar', 'kali': 'kali', 'nikah': 'nikah', 'kudu': 'kudu', 'efeknya': 'efek', 'tega': 'tega', 'lihat': 'lihat', 'bb': 'bb', 'turun': 'turun', 'surat': 'surat', 'puskesmas': 'puskesmas', 'catin': 'catin', 'dikasih': 'kasih', 'manten': 'manten', 'dipelosok': 'pelosok', 'aturan': 'atur', 'sungguh': 'sungguh', 'memepersulit': 'sulit', 'jarak': 'jarak', 'lokasi': 'lokasi', 'mantenn': 'mantenn', 'bolak': 'bolak', 'balek': 'balek', 'cuman': 'cuman', 'ngurussin': 'ngurussin', 'ribet': 'ribet', 'pkul': 'pkul', 'sebentar': 'sebentar', 'dokter': 'dokter', 'aztraveneca': 'aztraveneca', 'untung': 'untung', 'aman ...
# ------------------------

# %%
# stemmed
def stemming(text):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    text = [stemmer.stem(token) for token in text]
    text = ' '.join(text)
    return text
   
df['STEMMER'] = df['STOP_REMOVAL'].apply(stemming)
df.head(10)
# Out:
#                                             komentar  \
# 0  sy vaksin  mei jam  pagi setelah vaksin tidur ...
# 1                                             aamiin
# 2           yg hawatirkan itu epek jangka panjangnya
# 3  setelah vaksin siang jam  malam tidur terbangu...
# 4  saya  th tinggal di jerman telah di vaksin ast...
# 5  sy sekeluarga tetep nunggu vaksin nusantara aj...
# 6  alhamdulillah yang sudah di vaksin semoga seha...
# 7  saya tadi siang vaksin pertama astra di pasar ...
# 8  saya vaksin astrazeneca tgl  mei pagi malamnya...
# 9  saya pun sudah disuntik dgn vaksin az nie teng...
#
#                                         TOKENIZATION  \
# 0  [saya, vaksin, mei, jam, pagi, setelah, vaksin...
# 1                                             [amin]
# 2  [yang, hawatirkan, itu, efek, jangka, panjangnya]
# 3  [setelah, vaksin, siang, jam, malam, tidur, te...
# 4  [saya, tahu, tinggal, di, jerman, telah, di, v...
# 5  [saya, sekeluarga, tetap, tunggu, vaksin, nusa...
# 6  [alhamdulillah, yang, sudah, di, vaksin, semog...
# 7  [saya, tadi, siang, vaksin, pertama, astrazene...
# 8  [saya, vaksin, astrazeneca, tanggal, mei, pagi...
# 9  [saya, pun, sudah, disuntik, dengan, vaksin, a...
#
#                                         STOP_REMOVAL  \
# 0  [vaksin, mei, jam, pagi, vaksin, tidur, jam, a...
# 1                                             [amin]
# 2             [hawatirkan, efek, jangka, panjangnya]
# 3  [vaksin, siang, jam, malam, tidur, terbangun, ...
# 4  [tinggal, jerman, vaksin, astrazeneca, februar...
# 5  [sekeluarga, tunggu, vaksin, nusantara, ajahh,...
# 6  [alhamdulillah, vaksin, semoga, sehat, umur, a...
# 7  [siang, vaksin, astrazeneca, pasar, pagi, mang...
# 8  [vaksin, astrazeneca, tanggal, mei, pagi, mala...
# 9  [disuntik, vaksin, astrazeneca, tengahari, ken...
#
#                                              STEMMER
# 0  vaksin mei jam pagi vaksin tidur jam alhamduli...
# 1                                               amin
# 2                     hawatirkan efek jangka panjang
# 3  vaksin siang jam malam tidur bangun badan gigi...
# 4  tinggal jerman vaksin astrazeneca february kem...
# 5  keluarga tunggu vaksin nusantara ajahh komorbi...
# 6          alhamdulillah vaksin moga sehat umur amin
# 7  siang vaksin astrazeneca pasar pagi mangga jam...
# 8  vaksin astrazeneca tanggal mei pagi malam meri...
# 9  suntik vaksin astrazeneca tengahari kena sunti...

# %%
df.to_csv(r'C:\Users\aldi\PreProcessing.csv')
